# %%
import pandas as pd

volcanoes = pd.read_csv('Data/holocene_eruptions.csv')

# %%
volcanoes.head(5)
# Out:
#    Number                       Name  Country                          Region  \
# 0  210010  West Eifel Volcanic Field  Germany  Mediterranean and Western Asia
# 1  210020            Chaine des Puys   France  Mediterranean and Western Asia
# 2  210030        Olot Volcanic Field    Spain  Mediterranean and Western Asia
# 3  210040   Calatrava Volcanic Field    Spain  Mediterranean and Western Asia
# 4  211001                 Larderello    Italy  Mediterranean and Western Asia
#
#                   Type  Activity Evidence Last Known Eruption  Latitude  \
# 0              Maar(s)     Eruption Dated            8300 BCE    50.170
# 1         Lava dome(s)     Eruption Dated            4040 BCE    45.775
# 2  Pyroclastic cone(s)  Evidence Credible             Unknown    42.170
# 3  Pyroclastic cone(s)     Eruption Dated            3600 BCE    38.870
# 4  Explosion crater(s)  Eruption Observed             1282 CE    43.250
#
# ...

# %%
volcanoes.columns.tolist()
# Out:
# ['Number',
#  'Name',
#  'Country',
#  'Region',
#  'Type',
#  'Activity Evidence',
#  'Last Known Eruption',
#  'Latitude',
#  'Longitude',
#  'Elevation (Meters)',
#  'Dominant Rock Type',
#  'Tectonic Setting']

# %%
# Number of volcanoes in each region
volcanoes.groupby('Region')['Name'].count()
# Out:
# Region
# Africa and Red Sea                131
# Alaska                             88
# Antarctica                         34
# Atlantic Ocean                     30
# Canada and Western USA             71
# Hawaii and Pacific Ocean           33
# Iceland and Arctic Ocean           34
# Indonesia                         142
# Japan, Taiwan, Marianas           141
# Kamchatka and Mainland Asia       132
# Kuril Islands                      46
# Mediterranean and Western Asia     44
# Melanesia and Australia            80
# Middle East and Indian Ocean       46
# México and Central America        120
# New Zealand to Fiji                60
# Philippines and SE Asia            62
# South America                     197
# West Indies                        17
# Name: Name, dtype: int64

# %%
# Get the tallest volcano in the Philippines

ph_max_elev = volcanoes[volcanoes['Country'] == 'Philippines']['Elevation (Meters)'].max()

volcanoes[(volcanoes['Country'] == 'Philippines') & (volcanoes['Elevation (Meters)'] == ph_max_elev)]
# Out:
#      Number Name      Country                   Region           Type  \
# 507  271030  Apo  Philippines  Philippines and SE Asia  Stratovolcano
#
#      Activity Evidence Last Known Eruption  Latitude  Longitude  \
# 507  Unrest / Holocene             Unknown     6.989    125.269
#
#      Elevation (Meters)            Dominant Rock Type  \
# 507                2938  Andesite / Basaltic Andesite
#
#                                  Tectonic Setting
# 507  Subduction Zone / Continental Crust (>25 km)

# %%
# Checked a volcano with unusual negative elevation. Possibly underwater
volcanoes.loc[551, ['Name', 'Activity Evidence',
 'Last Known Eruption',
 'Latitude',
 'Longitude',
 'Elevation (Meters)',
 'Dominant Rock Type',
 'Tectonic Setting', 'Type']]
# Out:
# Name                                                     Unnamed
# Activity Evidence                              Eruption Observed
# Last Known Eruption                                      1854 CE
# Latitude                                                   20.33
# Longitude                                                 121.75
# Elevation (Meters)                                           -24
# Dominant Rock Type                                       No Data
# Tectonic Setting       Subduction Zone / Crust Thickness Unknown
# Type                                                   Submarine
# Name: 551, dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ph_volcanoes = volcanoes[volcanoes['Country'] == 'Philippines']
ph_volcanoes.head(5)
# Out:
#      Number     Name      Country                   Region  \
# 503  270010     Jolo  Philippines  Philippines and SE Asia
# 504  271010    Balut  Philippines  Philippines and SE Asia
# 505  271011   Parker  Philippines  Philippines and SE Asia
# 506  271020  Matutum  Philippines  Philippines and SE Asia
# 507  271030      Apo  Philippines  Philippines and SE Asia
#
#                     Type  Activity Evidence Last Known Eruption  Latitude  \
# 503  Pyroclastic cone(s)  Eruption Observed             1897 CE     6.013
# 504        Stratovolcano  Unrest / Holocene             Unknown     5.400
# 505        Stratovolcano  Eruption Observed             1641 CE     6.113
# 506        Stratovolcano     Eruption Dated             1290 CE     6.370
# 507        Stratovolcano  Unrest / Holocene             Unknown     6.989
#
#      Longitude  Elevation (Meters)            Dominant Rock Type  \
# 503    121.057                 811         Basalt / Picro-Basalt
# ...

# %%
# Distribution of volcano types in the Philippines
sns.countplot(ph_volcanoes, y='Type')
plt.show()
